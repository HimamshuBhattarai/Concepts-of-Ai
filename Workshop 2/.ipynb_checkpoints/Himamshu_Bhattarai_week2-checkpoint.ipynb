# %%
import pandas as pd

# %%
series = pd.Series([19,49,56,78], index= ['a','b','c','d'])
series
# Out:
# a    19
# b    49
# c    56
# d    78
# dtype: int64

# %%
series = pd.Series([19,49,56,78], index= ['a','b','c','d'])
series.shape, series.ndim, series.size
# Out:
# ((4,), 1, 4)

# %%
dataframe = pd.DataFrame({"A":[1,2,5,6,7], "B":[4,6,7,8,7]}, index= ['a','b','c','d','e'])
dataframe
# Out:
#    A  B
# a  1  4
# b  2  6
# c  5  7
# d  6  8
# e  7  7

# %%
dataframe = pd.DataFrame({"A":[1,2,5,6,7], "B":[4,6,7,8,7]}, index= ['a','b','c','d','e'])
dataframe.shape
# Out:
# (5, 2)

# %%
dataframe.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df = pd.read_csv("/content/drive/MyDrive/Concepts and technologies of AI/data.csv")
df.head() #mathi ko first 5 data dincha
# Out:
#            x          y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382
# 3  47.475640  71.546632
# 4  59.813208  87.230925

# %%
df.tail()# tala ko last five data dincha
# Out:
#             x          y
# 95  50.030174  81.536991
# 96  49.239765  72.111832
# 97  50.039576  85.232007
# 98  48.149859  66.224958
# 99  25.128485  53.454394

# %%
df.head(3)# mathi ko 3 aota data matra dine
# Out:
#            x          y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382

# %%
df.info() # datatype ko information dincha
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       100 non-null    float64
#  1   y       100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
df.columns #column dekhaucha
# Out:
# Index(['x', 'y'], dtype='object')

# %%
df.shape#shape dekhaucha
# Out:
# (100, 2)

# %%
df.describe()#basic description dincha
# Out:
#                 x           y
# count  100.000000  100.000000
# mean    48.958341   72.735051
# std      9.746379   16.658187
# min     25.128485   31.707006
# 25%     41.526164   60.788586
# 50%     49.634970   72.179542
# 75%     56.762631   83.215080
# max     70.346076  118.591217

# %%
df['x'] #similar to filter tya bhitra bhako coloum lincha yo case ma x ma bhako lai lincha
# Out:
# 0     32.502345
# 1     53.426804
# 2     61.530358
# 3     47.475640
# 4     59.813208
#         ...
# 95    50.030174
# 96    49.239765
# 97    50.039576
# 98    48.149859
# 99    25.128485
# Name: x, Length: 100, dtype: float64

# %%
df.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
import pandas as pd
from sklearn . datasets import load_iris
import numpy as np
iris = load_iris () # Load the Iris dataset
iris_df = pd.DataFrame (
    data = np.c_[iris['data'],iris['target']],columns = iris ['feature_names']+['target'])
np.random.seed (42) # Introduce missing values randomly
mask = np.random.rand(* iris_df . shape ) < 0.1 # 10%
iris_df[ mask ] = np.nan
print (" Missing Values in Iris Dataset :")
print ( iris_df.isnull().sum())
# Out:
#  Missing Values in Iris Dataset :
# sepal length (cm)    15
# sepal width (cm)     15
# petal length (cm)    19
# petal width (cm)     15
# target               19
# dtype: int64

# %%
iris_df_ffill = iris_df.ffill ()
iris_df_mean = iris_df.fillna ( iris_df . mean () )
iris_df_median = iris_df.fillna ( iris_df . median () )
iris_df_zero = iris_df.fillna (0)
iris_df_expanded = pd.concat ([ iris_df,iris_df_ffill.add_suffix ('_ffill '),iris_df_mean.add_suffix('_mean'),iris_df_median.add_suffix('_median'),iris_df_zero.add_suffix('_zero') ],axis =1)
print ("\ nDataset after Filling Missing Values :")
print ( iris_df_expanded.head () )
# Out:
# \ nDataset after Filling Missing Values :
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               NaN                1.4               0.2
# 2                NaN               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  sepal length (cm)_ffill   sepal width (cm)_ffill   \
# 0     0.0                       5.1                      3.5
# 1     0.0                       4.9                      3.5
# 2     0.0                       4.9                      3.2
# 3     0.0                       4.6                      3.1
# 4     0.0                       5.0                      3.6
#
#    petal length (cm)_ffill   petal width (cm)_ffill   target_ffill   ...  \
# ...

# %%
iris_df_expanded.isnull().sum()
# Out:
# sepal length (cm)           15
# sepal width (cm)            15
# petal length (cm)           19
# petal width (cm)            15
# target                      19
# sepal length (cm)_ffill      0
# sepal width (cm)_ffill       0
# petal length (cm)_ffill      0
# petal width (cm)_ffill       0
# target_ffill                 0
# sepal length (cm)_mean       0
# sepal width (cm)_mean        0
# petal length (cm)_mean       0
# petal width (cm)_mean        0
# target_mean                  0
# sepal length (cm)_median     0
# sepal width (cm)_median      0
# petal length (cm)_median     0
# petal width (cm)_median      0
# target_median                0
# sepal length (cm)_zero       0
# sepal width (cm)_zero        0
# petal length (cm)_zero       0
# petal width (cm)_zero        0
# target_zero                  0
# dtype: int64

# %%
#Worksheet-2
#Task-to-do

# %% [markdown]
# <h1>Problem 1</h1>

# %%
#Question-1
import pandas as pd

# %%
#Question-2
df = pd.read_csv('/content/drive/MyDrive/Concepts and technologies of AI/bank .csv')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#a)
df1 = df.select_dtypes(include='object')

# %%
df1.dtypes
# Out:
# job          object
# marital      object
# education    object
# default      object
# housing      object
# loan         object
# contact      object
# month        object
# poutcome     object
# y            object
# dtype: object

# %%
#b)
df.nunique()
# Out:
# age            77
# job            12
# marital         3
# education       4
# default         2
# balance      7168
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1573
# campaign       48
# pdays         559
# previous       41
# poutcome        4
# y               2
# dtype: int64

# %%
#c)
df.isnull().value_counts().sum()
# Out:
# 45211

# %%
#Question-3

df2 = df.select_dtypes(exclude=['object'])
df2.to_csv('banknumericdata.csv',index=False)

# %%
#Question-4

df2
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 0       58     2143    5       261         1     -1         0
# 1       44       29    5       151         1     -1         0
# 2       33        2    5        76         1     -1         0
# 3       47     1506    5        92         1     -1         0
# 4       33        1    5       198         1     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 45206   51      825   17       977         3     -1         0
# 45207   71     1729   17       456         2     -1         0
# 45208   72     5715   17      1127         5    184         3
# 45209   57      668   17       508         4     -1         0
# 45210   37     2971   17       361         2    188        11
#
# [45211 rows x 7 columns]

# %%
#Question-4

df2.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# <h1>Problem 2</h2>

# %%
#Question-1

df_med = pd.read_csv("/content/drive/MyDrive/Concepts and technologies of AI/medical_students_dataset.csv")

# %%
df_med
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
#Question-2

df_med.isnull().sum()
# Out:
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# Weight            20000
# Blood Type        20000
# BMI               20000
# Temperature       20000
# Heart Rate        20000
# Blood Pressure    20000
# Cholesterol       20000
# Diabetes          20000
# Smoking           20000
# dtype: int64

# %%
#Question-3

df_med_num = df_med.select_dtypes(exclude=['object'])
df_med_ob = df_med.select_dtypes(include=['object'])
df_med_num = df_med_num.fillna(df_med_num.mean())

# %%
df_med_num.isnull().sum()
# Out:
# Student ID        0
# Age               0
# Height            0
# Weight            0
# BMI               0
# Temperature       0
# Heart Rate        0
# Blood Pressure    0
# Cholesterol       0
# dtype: int64

# %%
new_med = pd.concat([df_med_num , df_med_ob ],axis=1)

# %%
new_med
# Out:
#            Student ID        Age      Height     Weight        BMI  \
# 0            1.000000  18.000000  161.777924  72.354947  27.645835
# 1            2.000000  26.021561  152.069157  47.630941  23.338869
# 2            3.000000  32.000000  182.537664  55.741083  16.729017
# 3        49974.042078  30.000000  182.112867  63.332207  19.096042
# 4            5.000000  23.000000  174.947103  46.234173  23.338869
# ...               ...        ...         ...        ...        ...
# 199995   49974.042078  24.000000  176.503260  95.756997  30.737254
# 199996   99997.000000  29.000000  163.917675  45.225194  16.831734
# 199997   99998.000000  34.000000  174.947103  99.648914  33.189303
# 199998   99999.000000  30.000000  156.446944  50.142824  20.486823
# 199999  100000.000000  20.000000  153.927409  99.928405  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol  Gender  \
# 0         98.600948        95.0      109.000000        203.0  Female
# ...

# %%
new_med.isnull().sum()
# Out:
# Student ID            0
# Age                   0
# Height                0
# Weight                0
# BMI                   0
# Temperature           0
# Heart Rate            0
# Blood Pressure        0
# Cholesterol           0
# Gender            20000
# Blood Type        20000
# Diabetes          20000
# Smoking           20000
# dtype: int64

# %%
#Question-4

new_med.duplicated().value_counts()
# Out:
# False    192356
# True       7644
# Name: count, dtype: int64

# %% [markdown]
# <h1>Problem 3</h1>

# %%
df_titanic = pd.read_csv("/content/drive/MyDrive/Concepts and technologies of AI/Titanic-Dataset.csv")

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Question-1

mask = df_titanic['Pclass'] == 1

# %%
df_titanic[mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
#Question-2

df_titanic["Age"].isnull().value_counts()
# Out:
# Age
# False    714
# True     177
# Name: count, dtype: int64

# %%
df_titanic['Age'].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
#Question-3

pd.get_dummies(data=df_titanic,columns=['Embarked']) #oneorencode
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Question-4

df_titanic['Sex'].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
df_titanic['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
#Question-4

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=df_titanic['Sex'], y=df_titanic['Survived'], data=df_titanic, hue='Sex')
plt.title('Survival Distribution by Gender')
plt.show()

# %%
#Question-5

sns.countplot(x='Embarked', data=df_titanic)
plt.show()
