# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h1>Problem 1</h1>

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Fare =df['Fare']

# %%
Fare1= pd.DataFrame(Fare)

# %%
Fare1
# Out:
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
Pclass_age = df[['Pclass','Age']]

# %%
Pclass_age
# Out:
#      Pclass   Age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
Survived_gender = df[['Survived','Sex']]

# %%
Survived_gender
# Out:
#      Survived     Sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %% [markdown]
# <h1>Problem 2</h1>

# %%
fare_gt_100 = df[df['Fare'] > 100]

# %%
fare_gt_100.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 27                   Fortune, Mr. Charles Alexander    male  19.0      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 118                        Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                            Lurette, Miss. Elise  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 27       2     19950  263.0000  C23 C25 C27        S
# 31       0  PC 17569  146.5208          B78        C
# 88       2     19950  263.0000  C23 C25 C27        S
# 118      1  PC 17558  247.5208      B58 B60        C
# ...

# %%
first_class = df[df['Pclass'] == 1 ]

# %%
first_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mask = df[(df['Age'] < 18) & (df['Sex'] == "female")]

# %%
mask.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22           23         1       3           McGowan, Miss. Anna "Annie"
# 24           25         0       3         Palsson, Miss. Torborg Danira
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 22  female  15.0      0      0   330923   8.0292   NaN        Q
# 24  female   8.0      3      1   349909  21.0750   NaN        S

# %%
embarked_c_or_s = df[df['Embarked'].isin(['C', 'S'])]

# %%
embarked_c_or_s
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
first_second_class = df[df['Pclass'].isin([1,2])]

# %%
first_second_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
df['fare_per_year'] = df['Fare'] /df['Age']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
high = df[df['fare_per_year'] > 5]

# %%
high.sort_values(by='Age',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 380          381         1       1               Bidois, Miss. Rosalie
# 716          717         1       1       Endres, Miss. Caroline Louise
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# ..           ...       ...     ...                                 ...
# 831          832         1       2     Richards, Master. George Sibley
# 644          645         1       3              Baclini, Miss. Eugenie
# 469          470         1       3       Baclini, Miss. Helene Barbara
# 755          756         1       2           Hamalainen, Master. Viljo
# 803          804         1       3     Thomas, Master. Assad Alexander
#
#         Sex    Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
high[['Name','fare_per_year']]
# Out:
#                                          Name  fare_per_year
# 7              Palsson, Master. Gosta Leonard      10.537500
# 16                       Rice, Master. Eugene      14.562500
# 27             Fortune, Mr. Charles Alexander      13.842105
# 43   Laroche, Miss. Simonne Marie Anne Andree      13.859733
# 50                 Panula, Master. Juha Niilo       5.669643
# ..                                        ...            ...
# 813        Andersson, Miss. Ebba Iris Alfrida       5.212500
# 824              Panula, Master. Urho Abraham      19.843750
# 827                     Mallet, Master. Andre      37.004200
# 831           Richards, Master. George Sibley      22.590361
# 850   Andersson, Master. Sigvard Harald Elias       7.818750
#
# [68 rows x 2 columns]

# %% [markdown]
# <h1>Part 2</h1>

# %%
df['fare_per_class'] = df['Fare'] /df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mask = df[(df['Age'] >18 ) & (df['Sex'] == "male")]

# %%
mask
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
mask.sort_values(by='fare_per_class',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
# 737          738         1       1              Lesurer, Mr. Gustave J  male
# 27            28         0       1      Fortune, Mr. Charles Alexander  male
# 438          439         0       1                   Fortune, Mr. Mark  male
# 118          119         0       1            Baxter, Mr. Quigg Edmond  male
# ..           ...       ...     ...                                 ...   ...
# 263          264         0       1               Harrison, Mr. William  male
# 271          272         1       3        Tornquist, Mr. William Henry  male
# 822          823         0       1     Reuchlin, Jonkheer. John George  male
# 302          303         0       3     Johnson, Mr. William Cahoone Jr  male
# 806          807         0       1              Andrews, Mr. Thomas Jr  male
#
# ...

# %%
df[['Name','Age','fare_per_class']]
# Out:
#                                                   Name   Age  fare_per_class
# 0                              Braund, Mr. Owen Harris  22.0        2.416667
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       71.283300
# 2                               Heikkinen, Miss. Laina  26.0        2.641667
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       53.100000
# 4                             Allen, Mr. William Henry  35.0        2.683333
# ..                                                 ...   ...             ...
# 886                              Montvila, Rev. Juozas  27.0        6.500000
# 887                       Graham, Miss. Margaret Edith  19.0       30.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN        7.816667
# 889                              Behr, Mr. Karl Howell  26.0       30.000000
# 890                                Dooley, Mr. Patrick  32.0        2.583333
#
# [891 rows x 3 columns]

# %% [markdown]
# <h1>EDA Part 2</h1>

# %%
total_fare = df['Fare'].sum()

# %%
total_fare
# Out:
# 28693.9493

# %%
df1=df[df['Pclass'] == 1]

# %%
pclass1 = df1['Fare'].sum()

# %%
df2=df[df['Pclass'] == 2]

# %%
pclass2 = df2['Fare'].sum()

# %%
df3=df[df['Pclass'] == 3]

# %%
pclass_3 = df3['Fare'].sum()

# %%
fare_list = [pclass1, pclass2, pclass_3]

# %%
fare_list
# Out:
# [18177.4125, 3801.8417, 6714.6951]

# %%
fare_list / total_fare
# Out:
# array([0.63349288, 0.13249629, 0.23401084])

# %% [markdown]
# <h1>Problem 2</h1>

# %%
df['age_group'] = pd.cut(df['Age'], bins=[0, 17, 64, 100], labels=['child', 'adult', 'senior'], right=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
total = df['PassengerId'].sum()

# %%
adult = (df['age_group'] == "adult").sum()

# %%
child = (df['age_group'] == "child").sum()

# %%
senior = (df['age_group'] == "senior").sum()

# %%
age_grp = [adult,child,senior]

# %%
prop = age_grp/total
# Out:
# array([1.51238343e-03, 2.51644497e-04, 3.27137846e-05])

# %%
percentage = (age_grp / total) * 100

# %%
percentage
# Out:
# array([0.15123834, 0.02516445, 0.00327138])
